# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
html = urlopen("http://search.11st.co.kr/Search.tmall?kwd=%25EB%2594%25B8%25EA%25B8%25B0")
bsObject = BeautifulSoup(html, "html.parser")

# %%
ul = bsObject.find("ul", {"class":"finder_lst"})

# %%
print(ul)
# Out:
# <ul class="finder_lst">
# <li>
# <a data-log-actionid-label="search_keyword" data-log-body='{"content_type":"TEXT","content_name":"생딸기","position_l1":"1"}' data-log-index="1" href="http://search.11st.co.kr/Search.tmall?kwd=생딸기" onclick="try{rakeLog.sendRakeLog(this);}catch(e){}ga('send', 'event', '통합검색(전체상품)', '연관검색어', '');">
# 							생딸기
# 						</a>
# </li>
# <li>
# <a data-log-actionid-label="search_keyword" data-log-body='{"content_type":"TEXT","content_name":"냉동과일","position_l1":"2"}' data-log-index="2" href="http://search.11st.co.kr/Search.tmall?kwd=냉동과일" onclick="try{rakeLog.sendRakeLog(this);}catch(e){}ga('send', 'event', '통합검색(전체상품)', '연관검색어', '');">
# 							냉동과일
# 						</a>
# </li>
# <li>
# ...

# %%
product_list = []
url_list = []

# %%
for value in ul:
    print(value.a.text.strip())
    print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-6253a1e4ebac> in <module>()
#       1 for value in ul:
# ----> 2     print(value.a.text.strip())
#       3     print()
#
# C:\Users\dnjsw\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, attr)
#     735             raise AttributeError(
#     736                 "'%s' object has no attribute '%s'" % (
# --> 737                     self.__class__.__name__, attr))
#     738
#     739     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'a'

# %%
keyword = ul.a.text.strip()
url = ul.a.attrs['href']

# %%
print(keyword, url)
# Out:
# 생딸기 http://search.11st.co.kr/Search.tmall?kwd=생딸기

# %%
dic = {'product':keyword,'url':url}

# %%
dic
# Out:
# {'product': '생딸기', 'url': 'http://search.11st.co.kr/Search.tmall?kwd=생딸기'}

# %%
print(strawberry)
# Out:
# [<ul class="finder_lst">
# <li>
# <a data-log-actionid-label="search_keyword" data-log-body='{"content_type":"TEXT","content_name":"생딸기","position_l1":"1"}' data-log-index="1" href="http://search.11st.co.kr/Search.tmall?kwd=생딸기" onclick="try{rakeLog.sendRakeLog(this);}catch(e){}ga('send', 'event', '통합검색(전체상품)', '연관검색어', '');">
# 							생딸기
# 						</a>
# </li>
# <li>
# <a data-log-actionid-label="search_keyword" data-log-body='{"content_type":"TEXT","content_name":"냉동과일","position_l1":"2"}' data-log-index="2" href="http://search.11st.co.kr/Search.tmall?kwd=냉동과일" onclick="try{rakeLog.sendRakeLog(this);}catch(e){}ga('send', 'event', '통합검색(전체상품)', '연관검색어', '');">
# 							냉동과일
# 						</a>
# </li>
# <li>
# ...

# %%
ul = bsObject.find("ul", {"class":"finder_lst"})
print(ul)
# Out:
# <ul class="finder_lst">
# <li>
# <a data-log-actionid-label="search_keyword" data-log-body='{"content_type":"TEXT","content_name":"생딸기","position_l1":"1"}' data-log-index="1" href="http://search.11st.co.kr/Search.tmall?kwd=생딸기" onclick="try{rakeLog.sendRakeLog(this);}catch(e){}ga('send', 'event', '통합검색(전체상품)', '연관검색어', '');">
# 							생딸기
# 						</a>
# </li>
# <li>
# <a data-log-actionid-label="search_keyword" data-log-body='{"content_type":"TEXT","content_name":"냉동과일","position_l1":"2"}' data-log-index="2" href="http://search.11st.co.kr/Search.tmall?kwd=냉동과일" onclick="try{rakeLog.sendRakeLog(this);}catch(e){}ga('send', 'event', '통합검색(전체상품)', '연관검색어', '');">
# 							냉동과일
# 						</a>
# </li>
# <li>
# ...

# %%
result = ul.a.text
print(result.strip())
# Out:
# 생딸기

# %%
ul = bsObject.find("ul", {"class":"finder_lst"})

# %%
ul.find_all()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-99964b886b33> in <module>()
# ----> 1 ul.find_all("li")
#
# C:\Users\dnjsw\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, attr)
#     735             raise AttributeError(
#     736                 "'%s' object has no attribute '%s'" % (
# --> 737                     self.__class__.__name__, attr))
#     738
#     739     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'find_all'

# %%
for a in ul:
    gref = a.attrs['href']
    text = a.string
    print(text,">",href)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-6ceb1379edd8> in <module>()
#       1 for a in ul:
# ----> 2     gref = a.attrs['href']
#       3     text = a.string
#       4     print(text,">",href)
#
# AttributeError: 'str' object has no attribute 'attrs'
